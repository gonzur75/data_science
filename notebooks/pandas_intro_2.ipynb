# %%
import os

import pandas as pd

raw_path = os.path.join("..", "data", "raw")
interim_path = os.path.join("..", "data", "interim")

# %%
df = pd.read_csv(os.path.join(raw_path, "artwork_data.csv"), low_memory=False)

# %%
df.shape
# Out:
# (69201, 20)

# %%
df.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
df.head(2) # x pierwszych wierszy
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
df.tail(2) # x ostatnich wierszy
# Out:
#            id accession_number             artist artistRole  artistId  \
# 69199  112306           T13868      Creed, Martin     artist      2760
# 69200  127035           T13869  Brunias, Agostino     artist      3824
#
#                                            title dateText  \
# 69199  Work No. 227: The lights going on and off     2000
# 69200           Dancing Scene in the West Indies  1764–96
#
#                     medium                                         creditLine  \
# 69199     Gallery lighting  Purchased with funds provided by Tate Members,...
# 69200  Oil paint on canvas  Purchased with assistance from Tate Patrons an...
#
#        year  acquisitionYear                           dimensions width  \
# 69199  2000           2013.0  Overall display dimensions variable   NaN
# 69200  1764           2013.0            unconfirmed: 508 x 660 mm   508
#
#       height  depth units inscription thumbnailCopyright  \
# ...

# %%
df.sample(5) # x losowych wierszy
# Out:
#            id accession_number                          artist artistRole  \
# 67021   25896           T11656          Malchair, John Baptist     artist
# 30329   54956           D27629  Turner, Joseph Mallord William     artist
# 47658   11920           P05009                   Piper, Edward     artist
# 69164  121189           T13833                Barlow, Phyllida     artist
# 46665     631           P04013                 Auerbach, Frank     artist
#
#        artistId                                              title  \
# 67021      2372                                         North View
# 30329       558  Sea Fortifications, or Ruined Castle: ?Lowesto...
# 47658      1773                                                  4
# 69164     10908                                           Untitled
# 46665       676                                 Reclining Figure I
#
#              dateText                  medium  \
# 67021  date not known        Etching on paper
# ...

# %%
df.describe() # opis danych
# Out:
#                   id      artistId  acquisitionYear         depth
# count   69201.000000  69201.000000     69156.000000   2514.000000
# mean    39148.026213   1201.063251      1910.646856    479.197772
# std     25980.468687   2019.422535        64.202148   1051.141734
# min         3.000000      0.000000      1823.000000      1.000000
# 25%     19096.000000    558.000000      1856.000000     48.250000
# 50%     37339.000000    558.000000      1856.000000    190.000000
# 75%     54712.000000   1137.000000      1982.000000    450.000000
# max    129068.000000  19232.000000      2013.000000  18290.000000

# %%
df.info()  # To nie jest pełna informacja, bo nie liczy np. jeżeli pomimo że danych nie ma podaje się zero
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69201 entries, 0 to 69200
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  69201 non-null  int64
#  1   accession_number    69201 non-null  object
#  2   artist              69201 non-null  object
#  3   artistRole          69201 non-null  object
#  4   artistId            69201 non-null  int64
#  5   title               69201 non-null  object
#  6   dateText            69201 non-null  object
#  7   medium              62817 non-null  object
#  8   creditLine          69198 non-null  object
#  9   year                63823 non-null  object
#  10  acquisitionYear     69156 non-null  float64
#  11  dimensions          66768 non-null  object
#  12  width               65860 non-null  object
#  13  height              65860 non-null  object
#  14  depth               2514 non-null   float64
# ...

# %%
len(df) == df.shape[0]  # mają zaimplementowane Sized protocol(__len__)
# Out:
# True

# %%
df = pd.read_csv(os.path.join(
    raw_path, "artwork_data.csv"),
    nrows=5,
    usecols=[0, 1, 2],
)
df
# Out:
#      id accession_number          artist
# 0  1035           A00001   Blake, Robert
# 1  1036           A00002   Blake, Robert
# 2  1037           A00003   Blake, Robert
# 3  1038           A00004   Blake, Robert
# 4  1039           A00005  Blake, William

# %%
# value = True
#
# def toggle(x):
#     global value
#     value = not value
#     return value
def toggle(odd=True):
    def inner(_):
        inner.value = not inner.value
        return inner.value

    inner.value = odd
    return inner


odd = range(1, 10, 2)

df = pd.read_csv(os.path.join(
    raw_path, "artwork_data.csv"),
    nrows=5,
    usecols=odd,
)

df
# Out:
#   accession_number artistRole  \
# 0           A00001     artist
# 1           A00002     artist
# 2           A00003     artist
# 3           A00004     artist
# 4           A00005     artist
#
#                                                title  \
# 0  A Figure Bowing before a Seated Old Man with h...
# 1  Two Drawings of Frightened Figures, Probably f...
# 2  The Preaching of Warning. Verso: An Old Man En...
# 3     Six Drawings of Figures with Outstretched Arms
# 4  The Circle of the Lustful: Francesca da Rimini...
#
#                                               medium    year
# 0  Watercolour, ink, chalk and graphite on paper....     NaN
# 1                                  Graphite on paper     NaN
# 2        Graphite on paper. Verso: graphite on paper  1785.0
# 3                                  Graphite on paper     NaN
# 4                            Line engraving on paper  1826.0

# %%
df.to_csv(os.path.join(interim_path, "artwork_data_interim.csv"))  # zapisywanie do pliku

# %%
df = pd.read_csv(os.path.join(raw_path, "artwork_data.csv"), low_memory=False)
df.artist  # Nie działa, jeżeli nazwa kolumny zawiera spacje, kropki albo zaczynają się od liczby. (mają niepoprawne nazwy identyfikatorów w python)
pd.unique(df['artist'])
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       shape=(3336,), dtype=object)

# %%
 # max mask index
import numpy as np

nd = np.array([1, 2, 3, 4, 5])
nd
# Out:
# array([1, 2, 3, 4, 5])

# %%
vector = nd > 2

# %%
np.array([1, 2, 3]) > np.array([2, 2, 2])
# Out:
# array([False, False,  True])

# %%
nd[vector]
# Out:
# array([3, 4, 5])

# %%
s = df['artist'] == 'Bacon, Francis'
s.sum()
# Out:
# np.int64(50)

# %%
s.value_counts()
# Out:
# artist
# False    69151
# True        50
# Name: count, dtype: int64

# %%
df['artist'].value_counts()
# Out:
# artist
# Turner, Joseph Mallord William    39389
# Jones, George                      1046
# Moore, Henry, OM, CH                623
# Daniell, William                    612
# Beuys, Joseph                       578
#                                   ...
# Ortman, George                        1
# Lane, Theodore                        1
# Janssen, Horst                        1
# Brüning, Peter                        1
# King, Scott                           1
# Name: count, Length: 3336, dtype: int64

# %%
df[['title', 'url']][
    df["artist"] == "Turner, Joseph Mallord William"]  #  wektor logiczny nie musi być w wybranym data frame
# Out:
#                                                    title  \
# 905    The Death of Actaeon, with a Distant View of M...
# 906               A Mountain Stream, Perhaps Bolton Glen
# 907                                         Frontispiece
# 908               Frontispiece, engraved by J.C. Easling
# 909                                      Bridge and Cows
# ...                                                  ...
# 63895                                      On the Thames
# 64496                             Figures at a Pier Head
# 64606  Villa dell’Ambrogiara e La Lastra, Road from P...
# 67664          The Northampton Election, 6 December 1830
# 67679                             The Blue Rigi, Sunrise
#
#                                                      url
# 905    http://www.tate.org.uk/art/artworks/turner-the...
# 906    http://www.tate.org.uk/art/artworks/turner-a-m...
# 907    http://www.tate.org.uk/art/artworks/turner-fro...
# ...

# %%
# nie używać:
# podwójna operacja, a można zrobić w jednej
# ryzyko przy zapisie, żeby nie nadpisać
df["artist"][1035:1100]
# Out:
# 1035        Beerbohm, Sir Max
# 1036        Beerbohm, Sir Max
# 1037        Beerbohm, Sir Max
# 1038        Beerbohm, Sir Max
# 1039        Beerbohm, Sir Max
#                 ...
# 1095    Potter, Helen Beatrix
# 1096    Potter, Helen Beatrix
# 1097    Potter, Helen Beatrix
# 1098    Potter, Helen Beatrix
# 1099    Potter, Helen Beatrix
# Name: artist, Length: 65, dtype: object

# %%
# optymalne rozwiązanie
# 'loc[rows, columns]'
df.loc[1035, 'artist']

df.loc[0::100]
# Out:
#            id accession_number                             artist artistRole  \
# 0        1035           A00001                      Blake, Robert     artist
# 100      1737           A00101  Burne-Jones, Sir Edward Coley, Bt     artist
# 200      6726           A00201              Houghton, Arthur Boyd     artist
# 300      7334           A00304                      Jones, George     artist
# 400      7434           A00404                      Jones, George     artist
# ...       ...              ...                                ...        ...
# 68800  121385           T13469                    Almeida, Helena     artist
# 68900  109713           T13569                    Yass, Catherine     artist
# 69000  123588           T13669                      Toren, Amikam     artist
# 69100  106717           T13769              Cruzvillegas, Abraham     artist
# 69200  127035           T13869                  Brunias, Agostino     artist
#
# ...

# %%
df.loc[:, ::2]
# Out:
#            id              artist  artistId                dateText  \
# 0        1035       Blake, Robert        38          date not known
# 1        1036       Blake, Robert        38          date not known
# 2        1037       Blake, Robert        38                 ?c.1785
# 3        1038       Blake, Robert        38          date not known
# 4        1039      Blake, William        39  1826–7, reprinted 1892
# ...       ...                 ...       ...                     ...
# 69196  122960  P-Orridge, Genesis     16646                    1975
# 69197  122961  P-Orridge, Genesis     16646                    1976
# 69198  121181        Hatoum, Mona      2365                    1996
# 69199  112306       Creed, Martin      2760                    2000
# 69200  127035   Brunias, Agostino      3824                 1764–96
#
#                                               creditLine  acquisitionYear  \
# 0                    Presented by Mrs John Richmond 1922           1922.0
# ...

# %%
df.loc[:5, ::-1]
# Out:
#                                                  url  \
# 0  http://www.tate.org.uk/art/artworks/blake-a-fi...
# 1  http://www.tate.org.uk/art/artworks/blake-two-...
# 2  http://www.tate.org.uk/art/artworks/blake-the-...
# 3  http://www.tate.org.uk/art/artworks/blake-six-...
# 4  http://www.tate.org.uk/art/artworks/blake-the-...
# 5  http://www.tate.org.uk/art/artworks/blake-ciam...
#
#                                         thumbnailUrl thumbnailCopyright  \
# 0  http://www.tate.org.uk/art/images/work/A/A00/A...                NaN
# 1  http://www.tate.org.uk/art/images/work/A/A00/A...                NaN
# 2  http://www.tate.org.uk/art/images/work/A/A00/A...                NaN
# 3  http://www.tate.org.uk/art/images/work/A/A00/A...                NaN
# 4  http://www.tate.org.uk/art/images/work/A/A00/A...                NaN
# 5  http://www.tate.org.uk/art/images/work/A/A00/A...                NaN
#
#   inscription units  depth height width             dimensions  \
# ...

# %%
df.loc[:5, [2, 5, 7]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df.loc[:5, [2, 5, 7]]
#
# File ~/workspace/data_sience/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/workspace/data_sience/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.iloc[:5, [2, 5, 7]]
# Out:
#            artist                                              title  \
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                               medium
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
# 4                            Line engraving on paper

# %%
df.loc[:5, ['artist', "title", "medium"]]
# Out:
#            artist                                              title  \
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5  Blake, William      Ciampolo the Barrator Tormented by the Devils
#
#                                               medium
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
# 4                            Line engraving on paper
# 5                            Line engraving on paper

# %%
df.loc[[3, 5, 7], 'artist':'title']
# Out:
#            artist artistRole  artistId  \
# 3   Blake, Robert     artist        38
# 5  Blake, William     artist        39
# 7  Blake, William     artist        39
#
#                                                title
# 3     Six Drawings of Figures with Outstretched Arms
# 5      Ciampolo the Barrator Tormented by the Devils
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...

# %%
df.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
# Wiersze 2, 5, 7 dla kolumn na a

# %%
cols = [col for col in df.columns if col.startswith('a')]
df.loc[[2, 5, 7], df.columns.str.startswith('a')]
# Out:
#   accession_number          artist artistRole  artistId  acquisitionYear
# 2           A00003   Blake, Robert     artist        38           1922.0
# 5           A00006  Blake, William     artist        39           1919.0
# 7           A00008  Blake, William     artist        39           1919.0

# %%
# Wiersze 2,5,7 dla kolumn zaczynających się na a, nie mogą się kończyć na d
df.loc[[2, 5, 7], df.columns[(df.columns.str.startswith('a')) & ~(df.columns.str.endswith('d'))]]
df.loc[[2, 5, 7], np.logical_and(df.columns.str.startswith("a"), np.logical_not(df.columns.str.endswith("d")))]
# Out:
#   accession_number          artist artistRole  acquisitionYear
# 2           A00003   Blake, Robert     artist           1922.0
# 5           A00006  Blake, William     artist           1919.0
# 7           A00008  Blake, William     artist           1919.0

# %%
df.query("artist == 'Turner, Joseph Mallord William'")
# Out:
#           id accession_number                          artist     artistRole  \
# 905    14609           A00909  Turner, Joseph Mallord William         artist
# 906    14610           A00910  Turner, Joseph Mallord William         artist
# 907    14611           A00911  Turner, Joseph Mallord William         artist
# 908    14612           A00912  Turner, Joseph Mallord William         artist
# 909    14613           A00913  Turner, Joseph Mallord William         artist
# ...      ...              ...                             ...            ...
# 63895  23870           T08530  Turner, Joseph Mallord William  attributed to
# 64496  23868           T09131  Turner, Joseph Mallord William         artist
# 64606  23869           T09241  Turner, Joseph Mallord William         artist
# 67664  92401           T12321  Turner, Joseph Mallord William         artist
# 67679  89511           T12336  Turner, Joseph Mallord William         artist
#
# ...

# %%
df.columns = [col if '_' not in col else col.replace('_', ' ') for col in df.columns]

# %%
df.columns
# Out:
# Index(['id', 'accession number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
df.rename(columns={
    "artist": "Artist"
})
# Out:
#            id accession number              Artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.query(
    "`accession number` == 'A00001'")  # back tick, służą do zapisywania nazw kolumn niezgodnych z pythonowymi identyfikatorami
# Out:
#      id accession number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
#
#   thumbnailCopyright                                       thumbnailUrl  \
# 0                NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 0  http://www.tate.org.uk/art/artworks/blake-a-fi...

# %%
df.query("id > 10000")
# Out:
#            id accession number                             artist artistRole  \
# 83      20228           A00084  Burne-Jones, Sir Edward Coley, Bt     artist
# 99      20230           A00100  Burne-Jones, Sir Edward Coley, Bt     artist
# 103     20231           A00104  Burne-Jones, Sir Edward Coley, Bt     artist
# 106     20233           A00107  Burne-Jones, Sir Edward Coley, Bt     artist
# 111     19411           A00112                     Blake, William     artist
# ...       ...              ...                                ...        ...
# 69196  122960           T13865                 P-Orridge, Genesis     artist
# 69197  122961           T13866                 P-Orridge, Genesis     artist
# 69198  121181           T13867                       Hatoum, Mona     artist
# 69199  112306           T13868                      Creed, Martin     artist
# 69200  127035           T13869                  Brunias, Agostino     artist
#
# ...

# %%
# czy da się zrobić query z id większym od średniej wartości id
# query używają ludzie korzystający z SQL
m = df['id'].mean()
df.query('id > @m')
df.query('id > id.mean()')
# Out:
#            id accession number              artist artistRole  artistId  \
# 1185    69319           A01189       Jones, George     artist       300
# 1186    69320           A01190       Jones, George     artist       300
# 1187    69321           A01191       Jones, George     artist       300
# 1188    69322           A01192       Jones, George     artist       300
# 1189    69323           A01193       Jones, George     artist       300
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                            title        dateText  \
# ...

# %%
# To samo co wyżej tylko z użyciem iloc
df.loc[df['id'] > df['id'].mean()]
# Out:
#            id accession number              artist artistRole  artistId  \
# 1185    69319           A01189       Jones, George     artist       300
# 1186    69320           A01190       Jones, George     artist       300
# 1187    69321           A01191       Jones, George     artist       300
# 1188    69322           A01192       Jones, George     artist       300
# 1189    69323           A01193       Jones, George     artist       300
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                            title        dateText  \
# ...

# %%
# to nie są indeksy więc nie można użyć iloc
df.iloc[pd.to_numeric(df['id'] > df['id'].mean())]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[125], line 2
#       1 # tonie są indeksy więc nie można użyć iloc
# ----> 2 df.iloc[pd.to_numeric(df['id'] > df['id'].mean())]
#
# File ~/workspace/data_sience/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/workspace/data_sience/ds_notes/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1738, in _iLocIndexer._getitem_axis(self, key, axis)
#    1735     key = np.asarray(key)
#    1737 if com.is_bool_indexer(key):
# -> 1738     self._validate_key(key, axis)
#    1739     return self._getbool_axis(key, axis=axis)
# ...

# %%
df['width'].sort_values().tail()
# Out:
# 69188    NaN
# 69190    NaN
# 69191    NaN
# 69193    NaN
# 69199    NaN
# Name: width, dtype: object

# %%
df["width"] = pd.to_numeric(df['width'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69201 entries, 0 to 69200
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  69201 non-null  int64
#  1   accession number    69201 non-null  object
#  2   artist              69201 non-null  object
#  3   artistRole          69201 non-null  object
#  4   artistId            69201 non-null  int64
#  5   title               69201 non-null  object
#  6   dateText            69201 non-null  object
#  7   medium              62817 non-null  object
#  8   creditLine          69198 non-null  object
#  9   year                63823 non-null  object
#  10  acquisitionYear     69156 non-null  float64
#  11  dimensions          66768 non-null  object
#  12  width               65860 non-null  object
#  13  height              65860 non-null  object
#  14  depth               2514 non-null   float64
# ...

# %%
df['height'] = pd.to_numeric(df["height"], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69201 entries, 0 to 69200
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  69201 non-null  int64
#  1   accession number    69201 non-null  object
#  2   artist              69201 non-null  object
#  3   artistRole          69201 non-null  object
#  4   artistId            69201 non-null  int64
#  5   title               69201 non-null  object
#  6   dateText            69201 non-null  object
#  7   medium              62817 non-null  object
#  8   creditLine          69198 non-null  object
#  9   year                63823 non-null  object
#  10  acquisitionYear     69156 non-null  float64
#  11  dimensions          66768 non-null  object
#  12  width               65860 non-null  object
#  13  height              65859 non-null  float64
#  14  depth               2514 non-null   float64
# ...

# %%
area = df['height'] * df['width']
df = df.assign(area=area)  # ponieważ assaign zwraca nowy obiekt, więc trzeba podmineić stary

# %%
df
# Out:
#            id accession number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
# fn/methody -> return new value
# metody -> None, mutują obiekt na którym są wywoływane
x = "ala ma kota"
x.upper()
# Out:
# 'ALA MA KOTA'

# %%
df["area"].max()
# Out:
# np.float64(132462000.0)

# %%
df["area"].idxmax()
# Out:
# 1903

# %%
df.iloc[1903]
# Out:
# id                                                                98367
# accession number                                                AR00166
# artist                                                 Therrien, Robert
# artistRole                                                       artist
# artistId                                                           2312
# title                                  No Title (Table and Four Chairs)
# dateText                                                           2003
# medium                               Aluminium, steel, wood and plastic
# creditLine            ARTIST ROOMS Acquired jointly with the Nationa...
# year                                                               2003
# acquisitionYear                                                  2008.0
# dimensions            displayed: 8920 x 14850 mm object, each (Chair...
# width                                                            8920.0
# ...

# %%
df.loc[df["area"].idxmax(), "url"]
# Out:
# 'http://www.tate.org.uk/art/artworks/therrien-no-title-table-and-four-chairs-ar00166'

# %%
(
    df
    .loc[
        df["area"].idxmax(),
        "url"
    ]
)
# Out:
# 'http://www.tate.org.uk/art/artworks/therrien-no-title-table-and-four-chairs-ar00166'

# %%
df_small = df.iloc[49980:50019].copy()

# %%
df_small.to_excel(os.path.join(interim_path, "artwork_data_small.xlsx"))

# %%
df_small.to_excel(os.path.join(interim_path, "artwork_data_small.xlsx"), columns=["artist", "title", "year"])

# %%
writer = pd.ExcelWriter(os.path.join(interim_path, "multiple_sheets_data.xlsx"), engine='xlsxwriter')
df_small.to_excel(writer, sheet_name="preview", index=False)
df.iloc[:6520].to_excel(writer, sheet_name="complete", index=False)
writer.close()

# %%
import sqlite3

# %%
with sqlite3.connect(os.path.join(interim_path, "db.sqlite")) as conn:
    df_small.to_sql('Tate', conn)

# %%
with sqlite3.connect(os.path.join(interim_path, "db.sqlite")) as conn:
    df_sql = pd.read_sql('SELECT * FROM Tate', conn)

# %%
df_sql
# Out:
#     index     id accession number             artist artistRole  artistId  \
# 0   49980  16412           P07951               Wols     artist      2164
# 1   49981  16413           P07952               Wols     artist      2164
# 2   49982  16414           P07953               Wols     artist      2164
# 3   49983  16415           P07954               Wols     artist      2164
# 4   49984  16416           P07955               Wols     artist      2164
# 5   49985  16417           P07956               Wols     artist      2164
# 6   49986  16418           P07957               Wols     artist      2164
# 7   49987  16419           P07958               Wols     artist      2164
# 8   49988  16420           P07959               Wols     artist      2164
# 9   49989  16421           P07960               Wols     artist      2164
# 10  49990  16422           P07961               Wols     artist      2164
# 11  49991  16423           P07962               Wols     artist      2164
# ...

# %%
#chce zobaczyć ile dzieł sztuki było wystawionych w danym roku

# %%
df.columns
#
# Out:
# Index(['id', 'accession number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url', 'area'],
#       dtype='object')

# %%
# gdy brakuje danych:
# - czy da sie uzupełnić
# - czy są istotne

df['acquisitionYear'].isnull().sum()
# Out:
# np.int64(45)

# %%
df.loc[df['acquisitionYear'].isnull()]
# Out:
#            id accession number                          artist artistRole  \
# 40527   70275           D41510  Turner, Joseph Mallord William     artist
# 40530  102543           D41513  Turner, Joseph Mallord William     artist
# 40531  106178           D41514  Turner, Joseph Mallord William     artist
# 40532  108224           D41515  Turner, Joseph Mallord William     artist
# 40533  108227           D41516  Turner, Joseph Mallord William     artist
# 40534  108328           D41517  Turner, Joseph Mallord William     artist
# 40536  111177           D41519  Turner, Joseph Mallord William     artist
# 40537  115539           D41520  Turner, Joseph Mallord William     artist
# 40538  115540           D41521  Turner, Joseph Mallord William     artist
# 40539  115541           D41522  Turner, Joseph Mallord William     artist
# 40540  115542           D41523  Turner, Joseph Mallord William     artist
# 40541  115543           D41524  Turner, Joseph Mallord William     artist
# ...

# %%
df['acquisitionYear'].dropna(inplace=True)
df.dropna(subset=['acquisitionYear'], inplace=True, axis=0)

# %%
df.shape
# Out:
# (69156, 21)

# %%
df['acquisitionYear'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['acquisitionYear'] = df["acquisitionYear"].astype('int64')

# %%
df['acquisitionYear'].value_counts()
# Out:
# acquisitionYear
# 1856    37893
# 1997     3706
# 1975     3046
# 2009     1364
# 1979     1166
#         ...
# 1855        1
# 1873        1
# 1870        1
# 1863        1
# 1834        1
# Name: count, Length: 178, dtype: int64

# %%
df.groupby("acquisitionYear").size()
# Out:
# acquisitionYear
# 1823       1
# 1824       2
# 1826       4
# 1827       1
# 1828       3
#         ...
# 2009    1364
# 2010     392
# 2011     320
# 2012     514
# 2013     458
# Length: 178, dtype: int64

# %%
acquisition_year = df.groupby("acquisitionYear").size()

# %%
type(acquisition_year)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# dane s
acquisition_year.plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(x=acquisition_year.index, y=acquisition_year.values, c='goldenrod')
ax.set_yscale('log')
ax.set_title('Number of artworks acquired by year')
ax.set_xlabel("Acquisition year")
ax.set_ylabel("Number of artworks")

ticks = [year for year in acquisition_year.index if year % 10 == 0]

ax.set_xticks(ticks)
ax.set_xticklabels(ticks, rotation=45)
ax.grid()
ax.set_axisbelow(True)
fig.tight_layout()
plt.show()

# %%
fig.savefig(os.path.join("..", "reports", "figures", "tate_gallery_acquisition_year.png"))

# %%
fig.savefig(os.path.join("..", "reports", "figures", "tate_gallery_acquisition_year.svg"), format='svg')
